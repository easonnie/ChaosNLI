# %%
import sys
import os

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
from evaluation.model_perf_binned import show_abdnli_binned_plot, show_nli_binned_plot, model_perf_abdnli_binned, model_perf_snli_binned, model_perf_mnli_binned

# %matplotlib inline

# %% [markdown]
# ## The Factor of Agreement
# **Chaos NLI** is a dataset with 100 annotations per example. To study how human agreements will influence the model performance, we compute the entropy of the human label distribution for each data point. Then, we partition the datasets using the entropy quantiles as the cut points. This results in several bins with roughly equal number of data points whose entropy lies in a specific range.
#
# Please read our [paper](https://arxiv.org/abs/2010.03532) for more details.
#
# The cells below show the model performance on each bin.
#
# - **JSD:** [Jensen–Shannon distance](https://scipy.github.io/devdocs/generated/scipy.spatial.distance.jensenshannon.html)
# - **KL:** [Kullback–Leibler divergence](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.entropy.html)
# - **Old Acc.:** Model accuracy (w.r.t. the original ground truth labels)
# - **New Acc.:** Model accuracy (w.r.t. the new majority labels)

# %% [markdown]
# ### ChaosNLI-Alpha

# %%
model_perf_abdnli_binned()
# Out:
# 1532it [00:00, 48256.37it/s]
# Load Jsonl: /Users/yixin/projects/released_codebase/chaos_nli/data/chaosNLI_v1.0/chaosNLI_alphanli.jsonl
# ------------------------------------------------------------
# Data: ChaosNLI - Abductive Commonsense Reasoning (alphaNLI)
# Model: bert-base
# Entropy Range     	# of Example   	JSD       	KL        	Old Acc.  	New Acc.
# 0.000000-0.141441	282            	0.1616    	1.4724    	0.844     	0.8475
# 0.141441-0.242292	273            	0.2609    	2.3739    	0.7473    	0.7473
# 0.242292-0.436470	340            	0.3453    	3.9402    	0.6441    	0.6412
# 0.436470-0.760168	325            	0.3782    	4.8388    	0.5631    	0.5877
# 0.760168-1.000000	312            	0.4312    	5.9072    	0.5       	0.4776
# Model: xlnet-base
# Entropy Range     	# of Example   	JSD       	KL        	Old Acc.  	New Acc.
# 0.000000-0.141441	282            	0.149     	0.3569    	0.8759    	0.8723
# 0.141441-0.242292	273            	0.2071    	0.6828    	0.7985    	0.8059
# ...

# %%
show_abdnli_binned_plot('Accuracy')
# Out:
# 1532it [00:00, 42152.70it/s]
# Load Jsonl: /Users/yixin/projects/released_codebase/chaos_nli/data/chaosNLI_v1.0/chaosNLI_alphanli.jsonl

# %%
show_abdnli_binned_plot('JSD')
# Out:
# 1532it [00:00, 46222.88it/s]
# Load Jsonl: /Users/yixin/projects/released_codebase/chaos_nli/data/chaosNLI_v1.0/chaosNLI_alphanli.jsonl

# %% [markdown]
# ### ChaosNLI-(S+M)

# %%
model_perf_snli_binned()
# Out:
# 1514it [00:00, 41713.81it/s]
# Load Jsonl: /Users/yixin/projects/released_codebase/chaos_nli/data/chaosNLI_v1.0/chaosNLI_snli.jsonl
# ------------------------------------------------------------
# Data: ChaosNLI - Stanford Natural Language Inference (SNLI)
# Model: bert-base
# Entropy Range     	# of Example   	JSD       	KL        	Old Acc.  	New Acc.
# 0.000000-0.499916	295            	0.1316    	0.1901    	0.8678    	0.9356
# 0.499916-0.749164	311            	0.2048    	0.3579    	0.8039    	0.8521
# 0.749164-0.934068	300            	0.2448    	0.4865    	0.68      	0.7367
# 0.934068-1.058444	300            	0.2824    	0.6584    	0.6067    	0.6233
# 1.058444-1.583069	308            	0.3064    	0.7057    	0.5487    	0.5032
# Model: xlnet-base
# Entropy Range     	# of Example   	JSD       	KL        	Old Acc.  	New Acc.
# 0.000000-0.499916	295            	0.137     	0.2134    	0.8644    	0.9322
# 0.499916-0.749164	311            	0.1943    	0.3428    	0.8071    	0.8778
# ...

# %%
model_perf_mnli_binned()
# Out:
# 1599it [00:00, 47659.16it/s]
# Load Jsonl: /Users/yixin/projects/released_codebase/chaos_nli/data/chaosNLI_v1.0/chaosNLI_mnli_m.jsonl
# ------------------------------------------------------------
# Data: ChaosNLI - Multi-Genre Natural Language Inference (MNLI)
# Model: bert-base
# Entropy Range     	# of Example   	JSD       	KL        	Old Acc.  	New Acc.
# 0.080793-0.865734	318            	0.2715    	0.5811    	0.6792    	0.673
# 0.865734-1.031894	320            	0.3101    	0.7543    	0.6312    	0.5938
# 1.031894-1.155374	318            	0.302     	0.7119    	0.6195    	0.5566
# 1.155374-1.296415	323            	0.3036    	0.6955    	0.5975    	0.5325
# 1.296415-1.584381	320            	0.3402    	0.8587    	0.4688    	0.4406
# Model: xlnet-base
# Entropy Range     	# of Example   	JSD       	KL        	Old Acc.  	New Acc.
# 0.080793-0.865734	318            	0.2599    	0.5896    	0.6855    	0.717
# 0.865734-1.031894	320            	0.3081    	0.7686    	0.6906    	0.6156
# ...

# %%
show_nli_binned_plot('Accuracy')
# Out:
# 1514it [00:00, 44346.97it/s]
# 1599it [00:00, 46716.35it/s]
# Load Jsonl: /Users/yixin/projects/released_codebase/chaos_nli/data/chaosNLI_v1.0/chaosNLI_snli.jsonl
# Load Jsonl: /Users/yixin/projects/released_codebase/chaos_nli/data/chaosNLI_v1.0/chaosNLI_mnli_m.jsonl

# %%
show_nli_binned_plot('JSD')
# Out:
# 1514it [00:00, 48097.19it/s]
# 1599it [00:00, 44727.38it/s]
# Load Jsonl: /Users/yixin/projects/released_codebase/chaos_nli/data/chaosNLI_v1.0/chaosNLI_snli.jsonl
# Load Jsonl: /Users/yixin/projects/released_codebase/chaos_nli/data/chaosNLI_v1.0/chaosNLI_mnli_m.jsonl
