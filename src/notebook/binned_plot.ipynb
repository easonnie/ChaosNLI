# %%
import sys
import os

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
from evaluation.model_perf_binned import show_abdnli_binned_plot

# %matplotlib inline

# %%
show_abdnli_binned_plot('Accuracy')
# Out:
# 1532it [00:00, 48745.08it/s]
# Load Jsonl: /Users/yixin/projects/released_codebase/chaos_nli/data/chaosNLI_v1.0/chaosNLI_alphanli.jsonl
# Processed Bin Item Count: 1532
# Processed Bin Item Count: 1532
# Processed Bin Item Count: 1532
# Processed Bin Item Count: 1532
# Processed Bin Item Count: 1532
# Processed Bin Item Count: 1532
# Processed Bin Item Count: 1532
# Processed Bin Item Count: 1532
# Processed Bin Item Count: 1532

# %%
show_abdnli_binned_plot('JSD')
# Out:
# 1532it [00:00, 43587.23it/s]
# Load Jsonl: /Users/yixin/projects/released_codebase/chaos_nli/data/chaosNLI_v1.0/chaosNLI_alphanli.jsonl
# Processed Bin Item Count: 1532
# Processed Bin Item Count: 1532
# Processed Bin Item Count: 1532
# Processed Bin Item Count: 1532
# Processed Bin Item Count: 1532
# Processed Bin Item Count: 1532
# Processed Bin Item Count: 1532
# Processed Bin Item Count: 1532
# Processed Bin Item Count: 1532
